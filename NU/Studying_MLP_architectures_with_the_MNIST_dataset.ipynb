# %% [markdown]
# # Studying MLP architectures with the MNIST dataset

# %%
# Packages which are not installed in the SageMaker TF2 kernel
# !pip install matplotlib --quiet
# Out:
# WARNING: You are using pip version 20.0.2; however, version 20.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os

### tf2.x
import tensorflow as tf
from tensorflow import keras

### Data prep
from sklearn.model_selection import train_test_split

### Model evaluation
from sklearn.metrics import classification_report

# %%
# Some common settings
pd.set_option('max_columns', None)
pd.set_option('max_rows', 100)

# Global random state
np.random.seed(42)
tf.random.set_seed(42)

# Some common variables
PATH_DATA = "./datasets"
PATH_CHECKPOINT = './checkpoints'
root_logdir ='s3://tensor.board/logs'

# %%
# Custom functions
def reset_keras():
    keras.backend.clear_session()
    
def get_logdir():
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

# %% [markdown]
# ## Get the dataset

# %%
# Read the data into _raw np array
train_raw = np.loadtxt(f'{PATH_DATA}/train.csv', skiprows=1, delimiter=',')
X_test_raw = np.loadtxt(f'{PATH_DATA}/test.csv', skiprows=1, delimiter=',')

# Check the shape
print(train_raw.shape, X_test_raw.shape)
# Out:
# (42000, 785) (28000, 784)

# %%
# Training set
X = train_raw[:, 1:].copy()
y = train_raw[:, 0].copy()  # first column is label

# Test set
X_test = X_test_raw.copy()

# Check the shape
print(X.shape, y.shape, X_test.shape)
# Out:
# (42000, 784) (42000,) (28000, 784)

# %% [markdown]
# ## EDA

# %% [markdown]
# <hr>
#
# **Summary:** This MNIST dataset contains 42000 hand-written digits, with each a 28x28 (=784) dimension array. There is no class imbalance, nor contains any missing values.
#
# <hr>

# %%
# Print some randomly selected digits
size = 6

fig, axes = plt.subplots(1, size, figsize=(12, 12))
for i, j in enumerate(np.random.randint(0, X.shape[0], size)):
    plt.subplot(1, size, i+1)
    plt.title(y[j])
    plt.imshow(X[j].reshape(28, 28), cmap="gray")

# %%
# How's the label distribution
plt.hist(y, bins=10)
plt.show()

# %%
# Any missing values?
print("Missing values in training set:", np.isnan(X).sum())
print("Missing values in test set:", np.isnan(X_test).sum())
# Out:
# Missing values in training set: 0
# Missing values in test set: 0

# %% [markdown]
# ## Data processing

# %%
# Spliting into training and validation set
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=.2, random_state=42)

# Check the shape
print(X_train.shape, X_valid.shape, y_train.shape, y_valid.shape)
# Out:
# (33600, 784) (8400, 784) (33600,) (8400,)

# %%
# Scaling to between 0-1
X_train = X_train/255
X_valid = X_valid/255
X_test = X_test/255

# %% [markdown]
# ## Research design

# %% [markdown]
# <hr>
#
# **Summary:** We will conduct a 2x2 factorial design to test the effect of numer of hidden layer and neurons of a multilayer perceptron (MLP) on the model training time and performance (accuracy), using the MNIST dataset.
#
# * Experiment A: 1 hidden layer, 50 neurons
# * Experiment B: 1 hidden layer, 100 neurons
# * Experiment C: 2 hidden layers, 50 neurons each
# * Experiment D: 2 hidden layers, 100 neurons each
#
# <hr>

# %% [markdown]
# ### Experiment A: 1 hidden layer, 50 neurons

# %%
# Build the model
model = keras.models.Sequential([
    keras.layers.Dense(50, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                39250
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                510
# =================================================================
# Total params: 39,760
# Trainable params: 39,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",    # y is not one hot encoded
              optimizer=keras.optimizers.SGD(lr=0.01),   # default lr
              metrics=["accuracy"])                      # Kaggle evaluates with accuracy and not AUC

# %%
# Callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(f'{PATH_CHECKPOINT}/mnist_A.h5',
                                                save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(get_logdir(), update_freq='epoch')

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

# %%
# %%time

# Fit the model
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/100
# 33600/33600 [==============================] - 2s 69us/sample - loss: 0.9053 - accuracy: 0.7705 - val_loss: 0.4912 - val_accuracy: 0.8730
# Epoch 2/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.4160 - accuracy: 0.8885 - val_loss: 0.3817 - val_accuracy: 0.8932
# Epoch 3/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.3471 - accuracy: 0.9046 - val_loss: 0.3403 - val_accuracy: 0.9046
# Epoch 4/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.3126 - accuracy: 0.9129 - val_loss: 0.3169 - val_accuracy: 0.9107
# Epoch 5/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2897 - accuracy: 0.9194 - val_loss: 0.2994 - val_accuracy: 0.9144
# Epoch 6/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2722 - accuracy: 0.9241 - val_loss: 0.2833 - val_accuracy: 0.9189
# Epoch 7/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2582 - accuracy: 0.9283 - val_loss: 0.2743 - val_accuracy: 0.9226
# Epoch 8/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.2465 - accuracy: 0.9312 - val_loss: 0.2629 - val_accuracy: 0.9255
# Epoch 9/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2360 - accuracy: 0.9338 - val_loss: 0.2513 - val_accuracy: 0.9290
# Epoch 10/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2264 - accuracy: 0.9367 - val_loss: 0.2435 - val_accuracy: 0.9305
# Epoch 11/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2176 - accuracy: 0.9386 - val_loss: 0.2369 - val_accuracy: 0.9323
# Epoch 12/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2100 - accuracy: 0.9404 - val_loss: 0.2302 - val_accuracy: 0.9343
# Epoch 13/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.2027 - accuracy: 0.9425 - val_loss: 0.2248 - val_accuracy: 0.9358
# Epoch 14/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1965 - accuracy: 0.9444 - val_loss: 0.2179 - val_accuracy: 0.9370
# Epoch 15/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1901 - accuracy: 0.9466 - val_loss: 0.2139 - val_accuracy: 0.9400
# Epoch 16/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1848 - accuracy: 0.9474 - val_loss: 0.2080 - val_accuracy: 0.9394
# Epoch 17/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1787 - accuracy: 0.9495 - val_loss: 0.2045 - val_accuracy: 0.9408
# Epoch 18/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1739 - accuracy: 0.9509 - val_loss: 0.1984 - val_accuracy: 0.9424
# Epoch 19/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1690 - accuracy: 0.9520 - val_loss: 0.1953 - val_accuracy: 0.9436
# Epoch 20/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1645 - accuracy: 0.9535 - val_loss: 0.1917 - val_accuracy: 0.9445
# Epoch 21/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1599 - accuracy: 0.9555 - val_loss: 0.1895 - val_accuracy: 0.9458
# Epoch 22/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1555 - accuracy: 0.9565 - val_loss: 0.1842 - val_accuracy: 0.9477
# Epoch 23/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1516 - accuracy: 0.9578 - val_loss: 0.1813 - val_accuracy: 0.9485
# Epoch 24/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1479 - accuracy: 0.9585 - val_loss: 0.1783 - val_accuracy: 0.9506
# Epoch 25/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1442 - accuracy: 0.9600 - val_loss: 0.1770 - val_accuracy: 0.9501
# Epoch 26/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.1408 - accuracy: 0.9611 - val_loss: 0.1722 - val_accuracy: 0.9513
# Epoch 27/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1373 - accuracy: 0.9615 - val_loss: 0.1706 - val_accuracy: 0.9523
# Epoch 28/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1342 - accuracy: 0.9626 - val_loss: 0.1681 - val_accuracy: 0.9523
# Epoch 29/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1312 - accuracy: 0.9635 - val_loss: 0.1668 - val_accuracy: 0.9536
# Epoch 30/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1283 - accuracy: 0.9644 - val_loss: 0.1640 - val_accuracy: 0.9533
# Epoch 31/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1256 - accuracy: 0.9657 - val_loss: 0.1613 - val_accuracy: 0.9551
# Epoch 32/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1229 - accuracy: 0.9660 - val_loss: 0.1601 - val_accuracy: 0.9555
# Epoch 33/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1204 - accuracy: 0.9668 - val_loss: 0.1584 - val_accuracy: 0.9545
# Epoch 34/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.1180 - accuracy: 0.9676 - val_loss: 0.1568 - val_accuracy: 0.9548
# Epoch 35/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1155 - accuracy: 0.9685 - val_loss: 0.1549 - val_accuracy: 0.9550
# Epoch 36/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1132 - accuracy: 0.9692 - val_loss: 0.1541 - val_accuracy: 0.9548
# Epoch 37/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1113 - accuracy: 0.9699 - val_loss: 0.1525 - val_accuracy: 0.9555
# Epoch 38/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1092 - accuracy: 0.9701 - val_loss: 0.1510 - val_accuracy: 0.9565
# Epoch 39/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.1071 - accuracy: 0.9703 - val_loss: 0.1511 - val_accuracy: 0.9555
# Epoch 40/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1051 - accuracy: 0.9720 - val_loss: 0.1481 - val_accuracy: 0.9557
# Epoch 41/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.1032 - accuracy: 0.9724 - val_loss: 0.1471 - val_accuracy: 0.9567
# Epoch 42/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1014 - accuracy: 0.9730 - val_loss: 0.1453 - val_accuracy: 0.9563
# Epoch 43/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0998 - accuracy: 0.9733 - val_loss: 0.1443 - val_accuracy: 0.9583
# Epoch 44/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0978 - accuracy: 0.9738 - val_loss: 0.1437 - val_accuracy: 0.9586
# Epoch 45/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0964 - accuracy: 0.9743 - val_loss: 0.1424 - val_accuracy: 0.9588
# Epoch 46/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0948 - accuracy: 0.9741 - val_loss: 0.1421 - val_accuracy: 0.9587
# Epoch 47/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0929 - accuracy: 0.9754 - val_loss: 0.1416 - val_accuracy: 0.9587
# Epoch 48/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0916 - accuracy: 0.9750 - val_loss: 0.1402 - val_accuracy: 0.9594
# Epoch 49/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0901 - accuracy: 0.9766 - val_loss: 0.1390 - val_accuracy: 0.9594
# Epoch 50/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0885 - accuracy: 0.9766 - val_loss: 0.1389 - val_accuracy: 0.9594
# Epoch 51/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0874 - accuracy: 0.9765 - val_loss: 0.1377 - val_accuracy: 0.9589
# Epoch 52/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0857 - accuracy: 0.9775 - val_loss: 0.1362 - val_accuracy: 0.9601
# Epoch 53/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0848 - accuracy: 0.9774 - val_loss: 0.1350 - val_accuracy: 0.9589
# Epoch 54/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0832 - accuracy: 0.9782 - val_loss: 0.1352 - val_accuracy: 0.9598
# Epoch 55/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0821 - accuracy: 0.9784 - val_loss: 0.1334 - val_accuracy: 0.9606
# Epoch 56/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0808 - accuracy: 0.9790 - val_loss: 0.1366 - val_accuracy: 0.9605
# Epoch 57/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0797 - accuracy: 0.9791 - val_loss: 0.1331 - val_accuracy: 0.9598
# Epoch 58/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0783 - accuracy: 0.9791 - val_loss: 0.1325 - val_accuracy: 0.9601
# Epoch 59/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0773 - accuracy: 0.9798 - val_loss: 0.1317 - val_accuracy: 0.9598
# Epoch 60/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0761 - accuracy: 0.9799 - val_loss: 0.1326 - val_accuracy: 0.9613
# Epoch 61/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0752 - accuracy: 0.9802 - val_loss: 0.1308 - val_accuracy: 0.9614
# Epoch 62/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0740 - accuracy: 0.9801 - val_loss: 0.1303 - val_accuracy: 0.9607
# Epoch 63/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0731 - accuracy: 0.9807 - val_loss: 0.1303 - val_accuracy: 0.9607
# Epoch 64/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0720 - accuracy: 0.9810 - val_loss: 0.1303 - val_accuracy: 0.9604
# Epoch 65/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0710 - accuracy: 0.9812 - val_loss: 0.1287 - val_accuracy: 0.9611
# Epoch 66/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0700 - accuracy: 0.9818 - val_loss: 0.1288 - val_accuracy: 0.9611
# Epoch 67/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0689 - accuracy: 0.9818 - val_loss: 0.1289 - val_accuracy: 0.9614
# Epoch 68/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0680 - accuracy: 0.9821 - val_loss: 0.1279 - val_accuracy: 0.9608
# Epoch 69/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0671 - accuracy: 0.9826 - val_loss: 0.1273 - val_accuracy: 0.9617
# Epoch 70/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0661 - accuracy: 0.9830 - val_loss: 0.1270 - val_accuracy: 0.9613
# Epoch 71/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0652 - accuracy: 0.9828 - val_loss: 0.1269 - val_accuracy: 0.9624
# Epoch 72/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0645 - accuracy: 0.9838 - val_loss: 0.1259 - val_accuracy: 0.9626
# Epoch 73/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0635 - accuracy: 0.9838 - val_loss: 0.1263 - val_accuracy: 0.9619
# Epoch 74/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0629 - accuracy: 0.9835 - val_loss: 0.1256 - val_accuracy: 0.9617
# Epoch 75/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0619 - accuracy: 0.9843 - val_loss: 0.1259 - val_accuracy: 0.9627
# Epoch 76/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0610 - accuracy: 0.9843 - val_loss: 0.1241 - val_accuracy: 0.9625
# Epoch 77/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0603 - accuracy: 0.9846 - val_loss: 0.1259 - val_accuracy: 0.9619
# Epoch 78/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0594 - accuracy: 0.9846 - val_loss: 0.1240 - val_accuracy: 0.9631
# Epoch 79/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0586 - accuracy: 0.9852 - val_loss: 0.1232 - val_accuracy: 0.9636
# Epoch 80/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0577 - accuracy: 0.9855 - val_loss: 0.1243 - val_accuracy: 0.9636
# Epoch 81/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0570 - accuracy: 0.9854 - val_loss: 0.1239 - val_accuracy: 0.9629
# Epoch 82/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0564 - accuracy: 0.9858 - val_loss: 0.1239 - val_accuracy: 0.9631
# Epoch 83/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0556 - accuracy: 0.9865 - val_loss: 0.1244 - val_accuracy: 0.9635
# Epoch 84/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0550 - accuracy: 0.9860 - val_loss: 0.1226 - val_accuracy: 0.9635
# Epoch 85/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0545 - accuracy: 0.9861 - val_loss: 0.1220 - val_accuracy: 0.9631
# Epoch 86/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0537 - accuracy: 0.9870 - val_loss: 0.1226 - val_accuracy: 0.9631
# Epoch 87/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0529 - accuracy: 0.9871 - val_loss: 0.1238 - val_accuracy: 0.9630
# Epoch 88/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0521 - accuracy: 0.9872 - val_loss: 0.1227 - val_accuracy: 0.9627
# Epoch 89/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0516 - accuracy: 0.9874 - val_loss: 0.1221 - val_accuracy: 0.9635
# Epoch 90/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0509 - accuracy: 0.9872 - val_loss: 0.1223 - val_accuracy: 0.9629
# Epoch 91/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0503 - accuracy: 0.9875 - val_loss: 0.1214 - val_accuracy: 0.9646
# Epoch 92/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0497 - accuracy: 0.9877 - val_loss: 0.1206 - val_accuracy: 0.9635
# Epoch 93/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0490 - accuracy: 0.9879 - val_loss: 0.1212 - val_accuracy: 0.9637
# Epoch 94/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0485 - accuracy: 0.9884 - val_loss: 0.1202 - val_accuracy: 0.9642
# Epoch 95/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0479 - accuracy: 0.9882 - val_loss: 0.1205 - val_accuracy: 0.9644
# Epoch 96/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0473 - accuracy: 0.9887 - val_loss: 0.1208 - val_accuracy: 0.9652
# Epoch 97/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0467 - accuracy: 0.9886 - val_loss: 0.1215 - val_accuracy: 0.9643
# Epoch 98/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0462 - accuracy: 0.9888 - val_loss: 0.1201 - val_accuracy: 0.9645
# Epoch 99/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0457 - accuracy: 0.9890 - val_loss: 0.1201 - val_accuracy: 0.9650
# Epoch 100/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0450 - accuracy: 0.9893 - val_loss: 0.1200 - val_accuracy: 0.9650
# CPU times: user 4min 41s, sys: 33.2 s, total: 5min 14s
# Wall time: 3min 14s

# %% [markdown]
# #### Evaluate

# %%
# Performance on the validation set
y_pred = model.predict_classes(X_valid)

print(classification_report(y_valid, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.98164   0.98284   0.98224       816
#          1.0    0.98136   0.98460   0.98298       909
#          2.0    0.97006   0.95745   0.96371       846
#          3.0    0.96360   0.96051   0.96205       937
#          4.0    0.96407   0.95948   0.96177       839
#          5.0    0.96264   0.95442   0.95851       702
#          6.0    0.96612   0.98089   0.97345       785
#          7.0    0.95175   0.97200   0.96177       893
#          8.0    0.95793   0.95449   0.95621       835
#          9.0    0.95060   0.94153   0.94604       838
#
#     accuracy                        0.96500      8400
#    macro avg    0.96498   0.96482   0.96487      8400
# weighted avg    0.96501   0.96500   0.96498      8400

# %% [markdown]
# #### Predict

# %%
# Predict the classes
y_test = model.predict_classes(X_test)

# Prepare file for submission
submission = pd.DataFrame({'ImageId': list(range(1, 28001, 1)),
                           'Label': y_test})
submission.to_csv(f'{PATH_DATA}/submission_A.csv', index=False)

# %% [markdown]
# ### Experiment B: 1 hidden layer, 100 neurons

# %%
# Build the model
model = keras.models.Sequential([
    keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",    # y is not one hot encoded
              optimizer=keras.optimizers.SGD(lr=0.01),   # default lr
              metrics=["accuracy"])                      # Kaggle evaluates with accuracy and not AUC

# %%
# Callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(f'{PATH_CHECKPOINT}/mnist_B.h5',
                                                save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(get_logdir(), update_freq='epoch')

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

# %%
# %%time

# Fit the model
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/100
# 33600/33600 [==============================] - 2s 63us/sample - loss: 0.8111 - accuracy: 0.8003 - val_loss: 0.4642 - val_accuracy: 0.8776
# Epoch 2/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.4007 - accuracy: 0.8904 - val_loss: 0.3720 - val_accuracy: 0.8983
# Epoch 3/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.3411 - accuracy: 0.9043 - val_loss: 0.3341 - val_accuracy: 0.9068
# Epoch 4/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.3094 - accuracy: 0.9135 - val_loss: 0.3127 - val_accuracy: 0.9118
# Epoch 5/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.2869 - accuracy: 0.9192 - val_loss: 0.2949 - val_accuracy: 0.9160
# Epoch 6/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.2691 - accuracy: 0.9245 - val_loss: 0.2785 - val_accuracy: 0.9221
# Epoch 7/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2541 - accuracy: 0.9275 - val_loss: 0.2674 - val_accuracy: 0.9244
# Epoch 8/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2411 - accuracy: 0.9321 - val_loss: 0.2563 - val_accuracy: 0.9288
# Epoch 9/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2293 - accuracy: 0.9354 - val_loss: 0.2435 - val_accuracy: 0.9318
# Epoch 10/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.2187 - accuracy: 0.9382 - val_loss: 0.2350 - val_accuracy: 0.9335
# Epoch 11/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.2089 - accuracy: 0.9418 - val_loss: 0.2269 - val_accuracy: 0.9357
# Epoch 12/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.2000 - accuracy: 0.9441 - val_loss: 0.2191 - val_accuracy: 0.9385
# Epoch 13/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1916 - accuracy: 0.9464 - val_loss: 0.2133 - val_accuracy: 0.9392
# Epoch 14/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1842 - accuracy: 0.9477 - val_loss: 0.2054 - val_accuracy: 0.9423
# Epoch 15/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1770 - accuracy: 0.9508 - val_loss: 0.2013 - val_accuracy: 0.9425
# Epoch 16/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1707 - accuracy: 0.9518 - val_loss: 0.1942 - val_accuracy: 0.9443
# Epoch 17/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1641 - accuracy: 0.9550 - val_loss: 0.1891 - val_accuracy: 0.9458
# Epoch 18/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1584 - accuracy: 0.9560 - val_loss: 0.1832 - val_accuracy: 0.9474
# Epoch 19/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1532 - accuracy: 0.9571 - val_loss: 0.1790 - val_accuracy: 0.9486
# Epoch 20/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1482 - accuracy: 0.9584 - val_loss: 0.1752 - val_accuracy: 0.9504
# Epoch 21/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1432 - accuracy: 0.9604 - val_loss: 0.1723 - val_accuracy: 0.9504
# Epoch 22/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1385 - accuracy: 0.9620 - val_loss: 0.1670 - val_accuracy: 0.9523
# Epoch 23/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1343 - accuracy: 0.9632 - val_loss: 0.1646 - val_accuracy: 0.9514
# Epoch 24/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1302 - accuracy: 0.9640 - val_loss: 0.1608 - val_accuracy: 0.9543
# Epoch 25/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1266 - accuracy: 0.9656 - val_loss: 0.1589 - val_accuracy: 0.9542
# Epoch 26/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1230 - accuracy: 0.9659 - val_loss: 0.1550 - val_accuracy: 0.9557
# Epoch 27/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1194 - accuracy: 0.9674 - val_loss: 0.1528 - val_accuracy: 0.9557
# Epoch 28/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1162 - accuracy: 0.9693 - val_loss: 0.1496 - val_accuracy: 0.9573
# Epoch 29/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1129 - accuracy: 0.9693 - val_loss: 0.1486 - val_accuracy: 0.9571
# Epoch 30/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1102 - accuracy: 0.9703 - val_loss: 0.1454 - val_accuracy: 0.9587
# Epoch 31/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1072 - accuracy: 0.9710 - val_loss: 0.1427 - val_accuracy: 0.9596
# Epoch 32/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1046 - accuracy: 0.9717 - val_loss: 0.1412 - val_accuracy: 0.9588
# Epoch 33/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.1021 - accuracy: 0.9727 - val_loss: 0.1394 - val_accuracy: 0.9594
# Epoch 34/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0997 - accuracy: 0.9731 - val_loss: 0.1380 - val_accuracy: 0.9593
# Epoch 35/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0971 - accuracy: 0.9740 - val_loss: 0.1360 - val_accuracy: 0.9598
# Epoch 36/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0948 - accuracy: 0.9742 - val_loss: 0.1349 - val_accuracy: 0.9606
# Epoch 37/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0929 - accuracy: 0.9750 - val_loss: 0.1326 - val_accuracy: 0.9610
# Epoch 38/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0908 - accuracy: 0.9754 - val_loss: 0.1316 - val_accuracy: 0.9610
# Epoch 39/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0886 - accuracy: 0.9762 - val_loss: 0.1315 - val_accuracy: 0.9611
# Epoch 40/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0868 - accuracy: 0.9772 - val_loss: 0.1287 - val_accuracy: 0.9617
# Epoch 41/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0847 - accuracy: 0.9775 - val_loss: 0.1273 - val_accuracy: 0.9630
# Epoch 42/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0832 - accuracy: 0.9780 - val_loss: 0.1255 - val_accuracy: 0.9623
# Epoch 43/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0816 - accuracy: 0.9779 - val_loss: 0.1248 - val_accuracy: 0.9621
# Epoch 44/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0797 - accuracy: 0.9794 - val_loss: 0.1240 - val_accuracy: 0.9626
# Epoch 45/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0783 - accuracy: 0.9797 - val_loss: 0.1234 - val_accuracy: 0.9626
# Epoch 46/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0767 - accuracy: 0.9797 - val_loss: 0.1220 - val_accuracy: 0.9633
# Epoch 47/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0751 - accuracy: 0.9802 - val_loss: 0.1213 - val_accuracy: 0.9635
# Epoch 48/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0737 - accuracy: 0.9807 - val_loss: 0.1206 - val_accuracy: 0.9633
# Epoch 49/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0723 - accuracy: 0.9810 - val_loss: 0.1191 - val_accuracy: 0.9639
# Epoch 50/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0707 - accuracy: 0.9815 - val_loss: 0.1188 - val_accuracy: 0.9640
# Epoch 51/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0696 - accuracy: 0.9816 - val_loss: 0.1171 - val_accuracy: 0.9650
# Epoch 52/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0681 - accuracy: 0.9823 - val_loss: 0.1167 - val_accuracy: 0.9655
# Epoch 53/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0671 - accuracy: 0.9823 - val_loss: 0.1158 - val_accuracy: 0.9657
# Epoch 54/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0657 - accuracy: 0.9831 - val_loss: 0.1149 - val_accuracy: 0.9648
# Epoch 55/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0646 - accuracy: 0.9833 - val_loss: 0.1135 - val_accuracy: 0.9654
# Epoch 56/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0633 - accuracy: 0.9837 - val_loss: 0.1148 - val_accuracy: 0.9662
# Epoch 57/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0624 - accuracy: 0.9841 - val_loss: 0.1129 - val_accuracy: 0.9654
# Epoch 58/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0611 - accuracy: 0.9842 - val_loss: 0.1128 - val_accuracy: 0.9661
# Epoch 59/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0602 - accuracy: 0.9844 - val_loss: 0.1119 - val_accuracy: 0.9661
# Epoch 60/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0591 - accuracy: 0.9851 - val_loss: 0.1121 - val_accuracy: 0.9665
# Epoch 61/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0582 - accuracy: 0.9855 - val_loss: 0.1105 - val_accuracy: 0.9673
# Epoch 62/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0571 - accuracy: 0.9856 - val_loss: 0.1107 - val_accuracy: 0.9671
# Epoch 63/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0563 - accuracy: 0.9863 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 64/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0552 - accuracy: 0.9866 - val_loss: 0.1099 - val_accuracy: 0.9662
# Epoch 65/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0544 - accuracy: 0.9866 - val_loss: 0.1092 - val_accuracy: 0.9665
# Epoch 66/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0534 - accuracy: 0.9872 - val_loss: 0.1086 - val_accuracy: 0.9669
# Epoch 67/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0525 - accuracy: 0.9876 - val_loss: 0.1085 - val_accuracy: 0.9671
# Epoch 68/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0518 - accuracy: 0.9874 - val_loss: 0.1089 - val_accuracy: 0.9662
# Epoch 69/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0510 - accuracy: 0.9877 - val_loss: 0.1068 - val_accuracy: 0.9680
# Epoch 70/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0501 - accuracy: 0.9882 - val_loss: 0.1076 - val_accuracy: 0.9674
# Epoch 71/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0492 - accuracy: 0.9885 - val_loss: 0.1067 - val_accuracy: 0.9679
# Epoch 72/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0486 - accuracy: 0.9888 - val_loss: 0.1062 - val_accuracy: 0.9677
# Epoch 73/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0478 - accuracy: 0.9889 - val_loss: 0.1061 - val_accuracy: 0.9676
# Epoch 74/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0471 - accuracy: 0.9886 - val_loss: 0.1058 - val_accuracy: 0.9673
# Epoch 75/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0462 - accuracy: 0.9894 - val_loss: 0.1059 - val_accuracy: 0.9677
# Epoch 76/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0456 - accuracy: 0.9897 - val_loss: 0.1046 - val_accuracy: 0.9683
# Epoch 77/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0449 - accuracy: 0.9897 - val_loss: 0.1060 - val_accuracy: 0.9677
# Epoch 78/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0442 - accuracy: 0.9898 - val_loss: 0.1049 - val_accuracy: 0.9676
# Epoch 79/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0436 - accuracy: 0.9902 - val_loss: 0.1037 - val_accuracy: 0.9686
# Epoch 80/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0428 - accuracy: 0.9902 - val_loss: 0.1047 - val_accuracy: 0.9680
# Epoch 81/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0422 - accuracy: 0.9910 - val_loss: 0.1043 - val_accuracy: 0.9695
# Epoch 82/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0417 - accuracy: 0.9908 - val_loss: 0.1037 - val_accuracy: 0.9688
# Epoch 83/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0410 - accuracy: 0.9910 - val_loss: 0.1045 - val_accuracy: 0.9682
# Epoch 84/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0405 - accuracy: 0.9913 - val_loss: 0.1028 - val_accuracy: 0.9689
# Epoch 85/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0399 - accuracy: 0.9912 - val_loss: 0.1021 - val_accuracy: 0.9688
# Epoch 86/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0394 - accuracy: 0.9915 - val_loss: 0.1029 - val_accuracy: 0.9688
# Epoch 87/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0387 - accuracy: 0.9918 - val_loss: 0.1041 - val_accuracy: 0.9683
# Epoch 88/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0381 - accuracy: 0.9919 - val_loss: 0.1033 - val_accuracy: 0.9683
# Epoch 89/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0376 - accuracy: 0.9921 - val_loss: 0.1026 - val_accuracy: 0.9689
# Epoch 90/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0370 - accuracy: 0.9921 - val_loss: 0.1025 - val_accuracy: 0.9683
# Epoch 91/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0365 - accuracy: 0.9923 - val_loss: 0.1019 - val_accuracy: 0.9694
# Epoch 92/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0360 - accuracy: 0.9928 - val_loss: 0.1011 - val_accuracy: 0.9694
# Epoch 93/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0355 - accuracy: 0.9925 - val_loss: 0.1016 - val_accuracy: 0.9695
# Epoch 94/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0350 - accuracy: 0.9924 - val_loss: 0.1010 - val_accuracy: 0.9696
# Epoch 95/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0345 - accuracy: 0.9932 - val_loss: 0.1013 - val_accuracy: 0.9688
# Epoch 96/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0340 - accuracy: 0.9931 - val_loss: 0.1005 - val_accuracy: 0.9700
# Epoch 97/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0335 - accuracy: 0.9930 - val_loss: 0.1015 - val_accuracy: 0.9692
# Epoch 98/100
# 33600/33600 [==============================] - 2s 55us/sample - loss: 0.0331 - accuracy: 0.9932 - val_loss: 0.1010 - val_accuracy: 0.9700
# Epoch 99/100
# 33600/33600 [==============================] - 2s 56us/sample - loss: 0.0326 - accuracy: 0.9933 - val_loss: 0.1008 - val_accuracy: 0.9694
# Epoch 100/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0321 - accuracy: 0.9937 - val_loss: 0.1001 - val_accuracy: 0.9700
# CPU times: user 4min 40s, sys: 34.4 s, total: 5min 14s
# Wall time: 3min 14s

# %% [markdown]
# #### Evaluate

# %%
# Performance on the validation set
y_pred = model.predict_classes(X_valid)

print(classification_report(y_valid, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.97802   0.98162   0.97982       816
#          1.0    0.98142   0.98790   0.98465       909
#          2.0    0.97365   0.96099   0.96728       846
#          3.0    0.96459   0.95945   0.96201       937
#          4.0    0.97020   0.97020   0.97020       839
#          5.0    0.96532   0.95157   0.95839       702
#          6.0    0.97233   0.98471   0.97848       785
#          7.0    0.96875   0.97200   0.97037       893
#          8.0    0.96420   0.96766   0.96593       835
#          9.0    0.96067   0.96181   0.96124       838
#
#     accuracy                        0.97000      8400
#    macro avg    0.96992   0.96979   0.96984      8400
# weighted avg    0.96999   0.97000   0.96998      8400

# %% [markdown]
# #### Predict

# %%
# Predict the classes
y_test = model.predict_classes(X_test)

# Prepare file for submission
submission = pd.DataFrame({'ImageId': list(range(1, 28001, 1)),
                           'Label': y_test})
submission.to_csv(f'{PATH_DATA}/submission_B.csv', index=False)

# %% [markdown]
# ### Experiment C: 2 hidden layers, 50 neurons each

# %%
# Build the model
model = keras.models.Sequential([
    keras.layers.Dense(50, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(50, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 50)                39250
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# =================================================================
# Total params: 42,310
# Trainable params: 42,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",    # y is not one hot encoded
              optimizer=keras.optimizers.SGD(lr=0.01),   # default lr
              metrics=["accuracy"])                      # Kaggle evaluates with accuracy and not AUC

# %%
# Callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(f'{PATH_CHECKPOINT}/mnist_C.h5',
                                                save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(get_logdir(), update_freq='epoch')

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

# %%
# %%time

# Fit the model
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/100
# 33600/33600 [==============================] - 2s 68us/sample - loss: 1.0083 - accuracy: 0.7191 - val_loss: 0.4700 - val_accuracy: 0.8702
# Epoch 2/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.3917 - accuracy: 0.8874 - val_loss: 0.3539 - val_accuracy: 0.8974
# Epoch 3/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.3193 - accuracy: 0.9071 - val_loss: 0.3089 - val_accuracy: 0.9096
# Epoch 4/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.2802 - accuracy: 0.9190 - val_loss: 0.2836 - val_accuracy: 0.9158
# Epoch 5/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.2521 - accuracy: 0.9258 - val_loss: 0.2622 - val_accuracy: 0.9235
# Epoch 6/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.2303 - accuracy: 0.9318 - val_loss: 0.2407 - val_accuracy: 0.9292
# Epoch 7/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.2117 - accuracy: 0.9386 - val_loss: 0.2270 - val_accuracy: 0.9352
# Epoch 8/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1963 - accuracy: 0.9425 - val_loss: 0.2132 - val_accuracy: 0.9387
# Epoch 9/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1831 - accuracy: 0.9475 - val_loss: 0.1999 - val_accuracy: 0.9436
# Epoch 10/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1717 - accuracy: 0.9498 - val_loss: 0.1941 - val_accuracy: 0.9444
# Epoch 11/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1619 - accuracy: 0.9529 - val_loss: 0.1860 - val_accuracy: 0.9476
# Epoch 12/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1532 - accuracy: 0.9555 - val_loss: 0.1762 - val_accuracy: 0.9511
# Epoch 13/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1453 - accuracy: 0.9575 - val_loss: 0.1814 - val_accuracy: 0.9494
# Epoch 14/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1387 - accuracy: 0.9601 - val_loss: 0.1662 - val_accuracy: 0.9539
# Epoch 15/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1321 - accuracy: 0.9618 - val_loss: 0.1636 - val_accuracy: 0.9542
# Epoch 16/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.1268 - accuracy: 0.9635 - val_loss: 0.1617 - val_accuracy: 0.9536
# Epoch 17/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1206 - accuracy: 0.9659 - val_loss: 0.1561 - val_accuracy: 0.9565
# Epoch 18/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1158 - accuracy: 0.9666 - val_loss: 0.1511 - val_accuracy: 0.9555
# Epoch 19/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1112 - accuracy: 0.9679 - val_loss: 0.1486 - val_accuracy: 0.9560
# Epoch 20/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1071 - accuracy: 0.9693 - val_loss: 0.1467 - val_accuracy: 0.9588
# Epoch 21/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1029 - accuracy: 0.9706 - val_loss: 0.1460 - val_accuracy: 0.9568
# Epoch 22/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.0989 - accuracy: 0.9719 - val_loss: 0.1404 - val_accuracy: 0.9585
# Epoch 23/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0955 - accuracy: 0.9730 - val_loss: 0.1400 - val_accuracy: 0.9592
# Epoch 24/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0922 - accuracy: 0.9745 - val_loss: 0.1367 - val_accuracy: 0.9613
# Epoch 25/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0893 - accuracy: 0.9742 - val_loss: 0.1397 - val_accuracy: 0.9580
# Epoch 26/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0861 - accuracy: 0.9751 - val_loss: 0.1371 - val_accuracy: 0.9602
# Epoch 27/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0833 - accuracy: 0.9765 - val_loss: 0.1338 - val_accuracy: 0.9608
# Epoch 28/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0802 - accuracy: 0.9775 - val_loss: 0.1319 - val_accuracy: 0.9602
# Epoch 29/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0777 - accuracy: 0.9784 - val_loss: 0.1328 - val_accuracy: 0.9598
# Epoch 30/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.0751 - accuracy: 0.9790 - val_loss: 0.1303 - val_accuracy: 0.9612
# Epoch 31/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0726 - accuracy: 0.9800 - val_loss: 0.1264 - val_accuracy: 0.9615
# Epoch 32/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0705 - accuracy: 0.9806 - val_loss: 0.1282 - val_accuracy: 0.9621
# Epoch 33/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0682 - accuracy: 0.9807 - val_loss: 0.1275 - val_accuracy: 0.9621
# Epoch 34/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0661 - accuracy: 0.9816 - val_loss: 0.1310 - val_accuracy: 0.9606
# Epoch 35/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0640 - accuracy: 0.9824 - val_loss: 0.1253 - val_accuracy: 0.9621
# Epoch 36/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0618 - accuracy: 0.9832 - val_loss: 0.1263 - val_accuracy: 0.9619
# Epoch 37/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0600 - accuracy: 0.9833 - val_loss: 0.1247 - val_accuracy: 0.9631
# Epoch 38/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0583 - accuracy: 0.9846 - val_loss: 0.1232 - val_accuracy: 0.9624
# Epoch 39/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0562 - accuracy: 0.9849 - val_loss: 0.1263 - val_accuracy: 0.9624
# Epoch 40/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0547 - accuracy: 0.9851 - val_loss: 0.1242 - val_accuracy: 0.9626
# Epoch 41/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.0531 - accuracy: 0.9860 - val_loss: 0.1220 - val_accuracy: 0.9638
# Epoch 42/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.0518 - accuracy: 0.9856 - val_loss: 0.1213 - val_accuracy: 0.9639
# Epoch 43/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0503 - accuracy: 0.9870 - val_loss: 0.1215 - val_accuracy: 0.9640
# Epoch 44/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0484 - accuracy: 0.9874 - val_loss: 0.1228 - val_accuracy: 0.9633
# Epoch 45/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0473 - accuracy: 0.9875 - val_loss: 0.1250 - val_accuracy: 0.9624
# Epoch 46/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0457 - accuracy: 0.9885 - val_loss: 0.1226 - val_accuracy: 0.9649
# Epoch 47/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0441 - accuracy: 0.9887 - val_loss: 0.1209 - val_accuracy: 0.9650
# Epoch 48/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0428 - accuracy: 0.9896 - val_loss: 0.1222 - val_accuracy: 0.9648
# Epoch 49/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0413 - accuracy: 0.9899 - val_loss: 0.1198 - val_accuracy: 0.9655
# Epoch 50/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0404 - accuracy: 0.9900 - val_loss: 0.1217 - val_accuracy: 0.9639
# Epoch 51/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0391 - accuracy: 0.9907 - val_loss: 0.1182 - val_accuracy: 0.9661
# Epoch 52/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0378 - accuracy: 0.9910 - val_loss: 0.1200 - val_accuracy: 0.9651
# Epoch 53/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0371 - accuracy: 0.9911 - val_loss: 0.1204 - val_accuracy: 0.9657
# Epoch 54/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0355 - accuracy: 0.9916 - val_loss: 0.1204 - val_accuracy: 0.9649
# Epoch 55/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0346 - accuracy: 0.9917 - val_loss: 0.1193 - val_accuracy: 0.9667
# Epoch 56/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0336 - accuracy: 0.9926 - val_loss: 0.1238 - val_accuracy: 0.9650
# Epoch 57/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0329 - accuracy: 0.9924 - val_loss: 0.1205 - val_accuracy: 0.9661
# Epoch 58/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0315 - accuracy: 0.9931 - val_loss: 0.1220 - val_accuracy: 0.9651
# Epoch 59/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0307 - accuracy: 0.9932 - val_loss: 0.1212 - val_accuracy: 0.9649
# Epoch 60/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0299 - accuracy: 0.9937 - val_loss: 0.1234 - val_accuracy: 0.9660
# Epoch 61/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0291 - accuracy: 0.9936 - val_loss: 0.1217 - val_accuracy: 0.9673
# CPU times: user 2min 56s, sys: 20.5 s, total: 3min 17s
# Wall time: 2min 3s

# %% [markdown]
# #### Evaluate

# %%
# Performance on the validation set
y_pred = model.predict_classes(X_valid)

print(classification_report(y_valid, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.98037   0.97917   0.97977       816
#          1.0    0.97819   0.98680   0.98248       909
#          2.0    0.97708   0.95745   0.96716       846
#          3.0    0.95931   0.95624   0.95778       937
#          4.0    0.96770   0.96424   0.96597       839
#          5.0    0.95184   0.95726   0.95455       702
#          6.0    0.97100   0.98089   0.97592       785
#          7.0    0.97062   0.96193   0.96625       893
#          8.0    0.96364   0.95210   0.95783       835
#          9.0    0.93953   0.96420   0.95171       838
#
#     accuracy                        0.96607      8400
#    macro avg    0.96593   0.96603   0.96594      8400
# weighted avg    0.96616   0.96607   0.96608      8400

# %% [markdown]
# #### Predict

# %%
# Predict the classes
y_test = model.predict_classes(X_test)

# Prepare file for submission
submission = pd.DataFrame({'ImageId': list(range(1, 28001, 1)),
                           'Label': y_test})
submission.to_csv(f'{PATH_DATA}/submission_C.csv', index=False)

# %% [markdown]
# ### Experiment D: 2 hidden layers, 100 neurons each

# %%
# Build the model
model = keras.models.Sequential([
    keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",    # y is not one hot encoded
              optimizer=keras.optimizers.SGD(lr=0.01),   # default lr
              metrics=["accuracy"])                      # Kaggle evaluates with accuracy and not AUC

# %%
# Callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(f'{PATH_CHECKPOINT}/mnist_D.h5',
                                                save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(get_logdir(), update_freq='epoch')

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

# %%
# %%time

# Fit the model
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/100
# 33600/33600 [==============================] - 2s 67us/sample - loss: 0.8873 - accuracy: 0.7716 - val_loss: 0.4250 - val_accuracy: 0.8826
# Epoch 2/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.3566 - accuracy: 0.8987 - val_loss: 0.3319 - val_accuracy: 0.9060
# Epoch 3/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.2977 - accuracy: 0.9138 - val_loss: 0.2925 - val_accuracy: 0.9177
# Epoch 4/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.2637 - accuracy: 0.9247 - val_loss: 0.2703 - val_accuracy: 0.9227
# Epoch 5/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.2373 - accuracy: 0.9325 - val_loss: 0.2477 - val_accuracy: 0.9288
# Epoch 6/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.2163 - accuracy: 0.9381 - val_loss: 0.2270 - val_accuracy: 0.9370
# Epoch 7/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1983 - accuracy: 0.9423 - val_loss: 0.2137 - val_accuracy: 0.9394
# Epoch 8/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1831 - accuracy: 0.9472 - val_loss: 0.2001 - val_accuracy: 0.9448
# Epoch 9/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1696 - accuracy: 0.9518 - val_loss: 0.1863 - val_accuracy: 0.9481
# Epoch 10/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1581 - accuracy: 0.9553 - val_loss: 0.1816 - val_accuracy: 0.9505
# Epoch 11/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1479 - accuracy: 0.9576 - val_loss: 0.1741 - val_accuracy: 0.9496
# Epoch 12/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1387 - accuracy: 0.9604 - val_loss: 0.1641 - val_accuracy: 0.9533
# Epoch 13/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.1304 - accuracy: 0.9622 - val_loss: 0.1650 - val_accuracy: 0.9524
# Epoch 14/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1235 - accuracy: 0.9648 - val_loss: 0.1524 - val_accuracy: 0.9562
# Epoch 15/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1165 - accuracy: 0.9670 - val_loss: 0.1503 - val_accuracy: 0.9580
# Epoch 16/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.1103 - accuracy: 0.9684 - val_loss: 0.1470 - val_accuracy: 0.9577
# Epoch 17/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.1041 - accuracy: 0.9703 - val_loss: 0.1408 - val_accuracy: 0.9604
# Epoch 18/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0991 - accuracy: 0.9718 - val_loss: 0.1353 - val_accuracy: 0.9620
# Epoch 19/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0941 - accuracy: 0.9732 - val_loss: 0.1331 - val_accuracy: 0.9600
# Epoch 20/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0897 - accuracy: 0.9743 - val_loss: 0.1310 - val_accuracy: 0.9630
# Epoch 21/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0857 - accuracy: 0.9757 - val_loss: 0.1302 - val_accuracy: 0.9610
# Epoch 22/100
# 33600/33600 [==============================] - 2s 62us/sample - loss: 0.0813 - accuracy: 0.9774 - val_loss: 0.1252 - val_accuracy: 0.9633
# Epoch 23/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0777 - accuracy: 0.9785 - val_loss: 0.1240 - val_accuracy: 0.9639
# Epoch 24/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0741 - accuracy: 0.9799 - val_loss: 0.1220 - val_accuracy: 0.9639
# Epoch 25/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0713 - accuracy: 0.9809 - val_loss: 0.1209 - val_accuracy: 0.9649
# Epoch 26/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0680 - accuracy: 0.9815 - val_loss: 0.1178 - val_accuracy: 0.9657
# Epoch 27/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0652 - accuracy: 0.9827 - val_loss: 0.1168 - val_accuracy: 0.9646
# Epoch 28/100
# 33600/33600 [==============================] - 2s 60us/sample - loss: 0.0622 - accuracy: 0.9836 - val_loss: 0.1143 - val_accuracy: 0.9663
# Epoch 29/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0597 - accuracy: 0.9844 - val_loss: 0.1165 - val_accuracy: 0.9654
# Epoch 30/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0573 - accuracy: 0.9851 - val_loss: 0.1131 - val_accuracy: 0.9658
# Epoch 31/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0549 - accuracy: 0.9852 - val_loss: 0.1099 - val_accuracy: 0.9670
# Epoch 32/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0527 - accuracy: 0.9861 - val_loss: 0.1121 - val_accuracy: 0.9656
# Epoch 33/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0503 - accuracy: 0.9874 - val_loss: 0.1104 - val_accuracy: 0.9682
# Epoch 34/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0485 - accuracy: 0.9881 - val_loss: 0.1104 - val_accuracy: 0.9669
# Epoch 35/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0466 - accuracy: 0.9880 - val_loss: 0.1085 - val_accuracy: 0.9664
# Epoch 36/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0444 - accuracy: 0.9889 - val_loss: 0.1092 - val_accuracy: 0.9681
# Epoch 37/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0429 - accuracy: 0.9895 - val_loss: 0.1070 - val_accuracy: 0.9681
# Epoch 38/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0411 - accuracy: 0.9905 - val_loss: 0.1070 - val_accuracy: 0.9677
# Epoch 39/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0394 - accuracy: 0.9905 - val_loss: 0.1089 - val_accuracy: 0.9685
# Epoch 40/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0379 - accuracy: 0.9912 - val_loss: 0.1054 - val_accuracy: 0.9676
# Epoch 41/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0364 - accuracy: 0.9918 - val_loss: 0.1060 - val_accuracy: 0.9696
# Epoch 42/100
# 33600/33600 [==============================] - 2s 61us/sample - loss: 0.0352 - accuracy: 0.9919 - val_loss: 0.1046 - val_accuracy: 0.9683
# Epoch 43/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0339 - accuracy: 0.9928 - val_loss: 0.1056 - val_accuracy: 0.9688
# Epoch 44/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0322 - accuracy: 0.9933 - val_loss: 0.1062 - val_accuracy: 0.9680
# Epoch 45/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0313 - accuracy: 0.9933 - val_loss: 0.1067 - val_accuracy: 0.9693
# Epoch 46/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0300 - accuracy: 0.9938 - val_loss: 0.1060 - val_accuracy: 0.9685
# Epoch 47/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0287 - accuracy: 0.9942 - val_loss: 0.1054 - val_accuracy: 0.9681
# Epoch 48/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0278 - accuracy: 0.9940 - val_loss: 0.1062 - val_accuracy: 0.9689
# Epoch 49/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0266 - accuracy: 0.9946 - val_loss: 0.1053 - val_accuracy: 0.9689
# Epoch 50/100
# 33600/33600 [==============================] - 2s 58us/sample - loss: 0.0253 - accuracy: 0.9951 - val_loss: 0.1066 - val_accuracy: 0.9695
# Epoch 51/100
# 33600/33600 [==============================] - 2s 57us/sample - loss: 0.0248 - accuracy: 0.9951 - val_loss: 0.1056 - val_accuracy: 0.9690
# Epoch 52/100
# 33600/33600 [==============================] - 2s 59us/sample - loss: 0.0235 - accuracy: 0.9957 - val_loss: 0.1061 - val_accuracy: 0.9704
# CPU times: user 2min 30s, sys: 17.5 s, total: 2min 47s
# Wall time: 1min 44s

# %% [markdown]
# #### Evaluate

# %%
# Performance on the validation set
y_pred = model.predict_classes(X_valid)

print(classification_report(y_valid, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.98765   0.98039   0.98401       816
#          1.0    0.97831   0.99230   0.98525       909
#          2.0    0.96471   0.96927   0.96698       846
#          3.0    0.95860   0.96371   0.96115       937
#          4.0    0.96782   0.96782   0.96782       839
#          5.0    0.96006   0.95869   0.95937       702
#          6.0    0.97695   0.97197   0.97446       785
#          7.0    0.97395   0.96305   0.96847       893
#          8.0    0.96723   0.95449   0.96082       835
#          9.0    0.94811   0.95943   0.95374       838
#
#     accuracy                        0.96833      8400
#    macro avg    0.96834   0.96811   0.96821      8400
# weighted avg    0.96837   0.96833   0.96833      8400

# %% [markdown]
# #### Predict

# %%
# Predict the classes
y_test = model.predict_classes(X_test)

# Prepare file for submission
submission = pd.DataFrame({'ImageId': list(range(1, 28001, 1)),
                           'Label': y_test})
submission.to_csv(f'{PATH_DATA}/submission_D.csv', index=False)

# %% [markdown]
# ## Look at some wrongly recognized digits
#
# Digit 9 and 5 have the lowest F1-score. Notice that some of the images are hard to recognize even by human.

# %%
def show_wrong_digits(X_valid, y_valid, y_pred, digit):
    # Show 6 images
    size = 6
    # Get the indices where the model made a wrong prediction for the specified digit
    idx = np.where((y_pred != digit) & (y_valid == digit))
    
    # Show the images and predicted labels
    fig, axes = plt.subplots(1, size, figsize=(12, 12))
    for i, j in enumerate(np.random.choice(idx[0], size, replace=False)):
        plt.subplot(1, size, i+1)
        plt.title(y_pred[j])
        # Transform back into the original scale
        plt.imshow((X_valid[j]*255).reshape(28, 28), cmap="gray")

# %%
# Show some wrongly recognized digit 9
show_wrong_digits(X_valid, y_valid, y_pred, 9)

# %%
# Show some wrongly recognized digit 5
show_wrong_digits(X_valid, y_valid, y_pred, 5)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# <hr>
#
# | Experiment | Number of hidden layers | Number of neurons per layer | Model fitting time (s) | Validation set accuracy | Test set accuracy |
# | --- | --- | --- | --- | --- | --- |
# | A | 1 | 50 | 194 | 0.9650 | 0.96342 |
# | B | 1 | 100 | 194 | 0.9700 | 0.96871 |
# | C | 2 | 50 | 123 | 0.9661 | 0.9650 |
# | D | 2 | 100 | 104 | 0.9683 | 0.96671 |
#
# **Summary:** Experiment A has the simplest MLP architecture (1 hidden layer x 50 neurons) with 39760 parameters to train. Note that this model didn't converge quickly, and the fitting time is long (run all 100 epochs). In experiment B we have doubled the neurons in the hidden layer, making this model much more parameters (79510) to train. Note that this model also didn't converge quickly with long fitting time (run all 100 epochs).
#
# In experiment C, we have built the model with 2 hidden layers (50 neurons each) with 42310 parameters to train. Note that this model converges quicker and the early stopping callback kicks in. Thus we can fit the model in a shorter time. In experiment D, we have a 2 hidden layer model (100 neurons each) with 89610 parameters to train. This model converges quickly and we can stop the fitting the earliest.
#
# It seems reasonable to build a model with more layers and neurons than needed, and use early stopping technique to interupt model fitting. With modern hardware (this experiment was run on a machine with Nvidia T4 GPU), we generally can get a good performing model in a shorter time. To test this approach, we built a significantly more complex model with 3 hidden layers (500 menrons each), and the result looks promising.
#
# | Experiment | Number of hidden layers | Number of neurons per layer | Model fitting time (s) | Validation set accuracy | Test set accuracy |
# | --- | --- | --- | --- | --- | --- |
# | Final | 3 | 500 | 121 | 0.9726 | 0.97014 |
#
#
# <hr>

# %% [markdown]
# ![Screenshot%202020-05-16%20at%2023.07.25.png](attachment:Screenshot%202020-05-16%20at%2023.07.25.png)

# %% [markdown]
# ### Final: 3 hidden layers, 500 neurons each

# %%
# Build the model
model = keras.models.Sequential([
    keras.layers.Dense(500, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(500, activation="relu"),
    keras.layers.Dense(500, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 500)               392500
# _________________________________________________________________
# dense_11 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_12 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 898,510
# Trainable params: 898,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",    # y is not one hot encoded
              optimizer=keras.optimizers.SGD(lr=0.01),   # default lr
              metrics=["accuracy"])                      # Kaggle evaluates with accuracy and not AUC

# %%
# Callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(f'{PATH_CHECKPOINT}/mnist_D.h5',
                                                save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(get_logdir(), update_freq='epoch')

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

# %%
# %%time

# Fit the model
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, tensorboard_cb, early_stopping_cb])
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/100
#    32/33600 [..............................] - ETA: 3:00 - loss: 2.3399 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.264881). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.264881). Check your callbacks.
# 33600/33600 [==============================] - 4s 121us/sample - loss: 0.7687 - accuracy: 0.8115 - val_loss: 0.3663 - val_accuracy: 0.8937
# Epoch 2/100
# 33600/33600 [==============================] - 3s 91us/sample - loss: 0.2982 - accuracy: 0.9127 - val_loss: 0.2796 - val_accuracy: 0.9205
# Epoch 3/100
# 33600/33600 [==============================] - 3s 87us/sample - loss: 0.2412 - accuracy: 0.9300 - val_loss: 0.2324 - val_accuracy: 0.9337
# Epoch 4/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.2041 - accuracy: 0.9422 - val_loss: 0.2148 - val_accuracy: 0.9381
# Epoch 5/100
# 33600/33600 [==============================] - 3s 89us/sample - loss: 0.1762 - accuracy: 0.9491 - val_loss: 0.1889 - val_accuracy: 0.9444
# Epoch 6/100
# 33600/33600 [==============================] - 3s 87us/sample - loss: 0.1554 - accuracy: 0.9556 - val_loss: 0.1701 - val_accuracy: 0.9512
# Epoch 7/100
# 33600/33600 [==============================] - 3s 95us/sample - loss: 0.1376 - accuracy: 0.9606 - val_loss: 0.1595 - val_accuracy: 0.9538
# Epoch 8/100
# 33600/33600 [==============================] - 3s 90us/sample - loss: 0.1237 - accuracy: 0.9647 - val_loss: 0.1506 - val_accuracy: 0.9569
# Epoch 9/100
# 33600/33600 [==============================] - 3s 89us/sample - loss: 0.1107 - accuracy: 0.9680 - val_loss: 0.1365 - val_accuracy: 0.9615
# Epoch 10/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0998 - accuracy: 0.9723 - val_loss: 0.1320 - val_accuracy: 0.9619
# Epoch 11/100
# 33600/33600 [==============================] - 3s 91us/sample - loss: 0.0905 - accuracy: 0.9746 - val_loss: 0.1301 - val_accuracy: 0.9629
# Epoch 12/100
# 33600/33600 [==============================] - 3s 90us/sample - loss: 0.0818 - accuracy: 0.9774 - val_loss: 0.1187 - val_accuracy: 0.9655
# Epoch 13/100
# 33600/33600 [==============================] - 3s 84us/sample - loss: 0.0742 - accuracy: 0.9798 - val_loss: 0.1271 - val_accuracy: 0.9625
# Epoch 14/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0681 - accuracy: 0.9813 - val_loss: 0.1117 - val_accuracy: 0.9670
# Epoch 15/100
# 33600/33600 [==============================] - 3s 84us/sample - loss: 0.0623 - accuracy: 0.9831 - val_loss: 0.1164 - val_accuracy: 0.9644
# Epoch 16/100
# 33600/33600 [==============================] - 3s 86us/sample - loss: 0.0563 - accuracy: 0.9857 - val_loss: 0.1112 - val_accuracy: 0.9669
# Epoch 17/100
# 33600/33600 [==============================] - 3s 87us/sample - loss: 0.0507 - accuracy: 0.9868 - val_loss: 0.1062 - val_accuracy: 0.9682
# Epoch 18/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0466 - accuracy: 0.9876 - val_loss: 0.1004 - val_accuracy: 0.9690
# Epoch 19/100
# 33600/33600 [==============================] - 3s 89us/sample - loss: 0.0421 - accuracy: 0.9893 - val_loss: 0.0988 - val_accuracy: 0.9689
# Epoch 20/100
# 33600/33600 [==============================] - 3s 92us/sample - loss: 0.0386 - accuracy: 0.9905 - val_loss: 0.0964 - val_accuracy: 0.9699
# Epoch 21/100
# 33600/33600 [==============================] - 3s 82us/sample - loss: 0.0352 - accuracy: 0.9911 - val_loss: 0.0976 - val_accuracy: 0.9694
# Epoch 22/100
# 33600/33600 [==============================] - 3s 87us/sample - loss: 0.0319 - accuracy: 0.9926 - val_loss: 0.0957 - val_accuracy: 0.9707
# Epoch 23/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0290 - accuracy: 0.9937 - val_loss: 0.0947 - val_accuracy: 0.9706
# Epoch 24/100
# 33600/33600 [==============================] - 3s 83us/sample - loss: 0.0264 - accuracy: 0.9940 - val_loss: 0.0950 - val_accuracy: 0.9711
# Epoch 25/100
# 33600/33600 [==============================] - 3s 87us/sample - loss: 0.0238 - accuracy: 0.9951 - val_loss: 0.0945 - val_accuracy: 0.9704
# Epoch 26/100
# 33600/33600 [==============================] - 3s 86us/sample - loss: 0.0217 - accuracy: 0.9958 - val_loss: 0.0938 - val_accuracy: 0.9711
# Epoch 27/100
# 33600/33600 [==============================] - 3s 90us/sample - loss: 0.0200 - accuracy: 0.9960 - val_loss: 0.0916 - val_accuracy: 0.9727
# Epoch 28/100
# 33600/33600 [==============================] - 3s 85us/sample - loss: 0.0180 - accuracy: 0.9971 - val_loss: 0.0922 - val_accuracy: 0.9717
# Epoch 29/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0165 - accuracy: 0.9976 - val_loss: 0.0931 - val_accuracy: 0.9718
# Epoch 30/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.0928 - val_accuracy: 0.9715
# Epoch 31/100
# 33600/33600 [==============================] - 3s 88us/sample - loss: 0.0136 - accuracy: 0.9984 - val_loss: 0.0908 - val_accuracy: 0.9726
# Epoch 32/100
# 33600/33600 [==============================] - 3s 83us/sample - loss: 0.0125 - accuracy: 0.9989 - val_loss: 0.0954 - val_accuracy: 0.9710
# Epoch 33/100
# 33600/33600 [==============================] - 3s 84us/sample - loss: 0.0114 - accuracy: 0.9989 - val_loss: 0.0943 - val_accuracy: 0.9721
# Epoch 34/100
# 33600/33600 [==============================] - 3s 81us/sample - loss: 0.0104 - accuracy: 0.9991 - val_loss: 0.0955 - val_accuracy: 0.9725
# Epoch 35/100
# 33600/33600 [==============================] - 3s 85us/sample - loss: 0.0097 - accuracy: 0.9992 - val_loss: 0.0931 - val_accuracy: 0.9729
# Epoch 36/100
# 33600/33600 [==============================] - 3s 85us/sample - loss: 0.0088 - accuracy: 0.9993 - val_loss: 0.0947 - val_accuracy: 0.9721
# Epoch 37/100
# 33600/33600 [==============================] - 3s 84us/sample - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0937 - val_accuracy: 0.9740
# Epoch 38/100
# 33600/33600 [==============================] - 3s 82us/sample - loss: 0.0076 - accuracy: 0.9995 - val_loss: 0.0939 - val_accuracy: 0.9718
# Epoch 39/100
# 33600/33600 [==============================] - 3s 83us/sample - loss: 0.0069 - accuracy: 0.9996 - val_loss: 0.0955 - val_accuracy: 0.9738
# Epoch 40/100
# 33600/33600 [==============================] - 3s 86us/sample - loss: 0.0066 - accuracy: 0.9996 - val_loss: 0.0952 - val_accuracy: 0.9733
# Epoch 41/100
# 33600/33600 [==============================] - 3s 84us/sample - loss: 0.0061 - accuracy: 0.9996 - val_loss: 0.0959 - val_accuracy: 0.9740
# CPU times: user 2min 33s, sys: 19.3 s, total: 2min 52s
# Wall time: 2min 1s

# %% [markdown]
# ![Screenshot%202020-05-16%20at%2023.03.15.png](attachment:Screenshot%202020-05-16%20at%2023.03.15.png)

# %% [markdown]
# ### Evaluate

# %%
# Performance on the validation set
y_pred = model.predict_classes(X_valid)

print(classification_report(y_valid, y_pred, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#          0.0    0.98289   0.98529   0.98409       816
#          1.0    0.97516   0.99340   0.98420       909
#          2.0    0.97494   0.96572   0.97031       846
#          3.0    0.97097   0.96371   0.96733       937
#          4.0    0.97272   0.97735   0.97503       839
#          5.0    0.96143   0.95869   0.96006       702
#          6.0    0.97848   0.98471   0.98159       785
#          7.0    0.97654   0.97872   0.97763       893
#          8.0    0.96731   0.95689   0.96207       835
#          9.0    0.96403   0.95943   0.96172       838
#
#     accuracy                        0.97262      8400
#    macro avg    0.97245   0.97239   0.97240      8400
# weighted avg    0.97260   0.97262   0.97259      8400

# %% [markdown]
# ### Predict

# %%
# Predict the classes
y_test = model.predict_classes(X_test)

# Prepare file for submission
submission = pd.DataFrame({'ImageId': list(range(1, 28001, 1)),
                           'Label': y_test})
submission.to_csv(f'{PATH_DATA}/submission_final.csv', index=False)
